# %%
import requests
import pandas as pd

# %%
api_url = 'https://api.scryfall.com/bulk-data'
response = requests.get(api_url)
r = response.json()['data'][0]['download_uri']
r_1 = requests.get(r)

pd.DataFrame.from_dict(r_1.json())
# Out:
#       object                                    id  \
# 0       card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1       card  7050735c-b232-47a6-a342-01795bfd0d46
# 2       card  e718b21b-46d1-4844-985c-52745657b1ac
# 3       card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4       card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
# ...      ...                                   ...
# 28558   card  d6695fa8-881c-407c-91d9-3ac770372d35
# 28559   card  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 28560   card  22a6a5f1-1405-4efb-af3e-e1f58d664e99
# 28561   card  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 28562   card  000edc61-b3ae-49e3-87f4-0250fa6a4501
#
#                                   oracle_id    multiverse_ids   mtgo_id  \
# 0      0004ebd0-dfd6-4276-b4a6-de0003e94237           [15862]   15870.0
# 1      0006faf6-7a61-426c-9034-579f2cfcfa83          [370780]   49283.0
# 2      0007c283-5b7a-4c00-9ca1-b455c8dff8c3          [470580]   77122.0
# 3      000d5588-5a4c-434e-988d-396632ade42c           [83282]   22609.0
# 4      000e5d65-96c3-498b-bd01-72b1a1991850           [12380]   12637.0
# ...                                     ...               ...       ...
# 28558  fffa9334-3576-4f70-9605-2ad062cdbc69          [430770]   64646.0
# 28559  fffaa634-42a0-4038-b027-24f28754fec7          [571548]  101914.0
# 28560  fffcb71f-e802-436e-917d-eaa6607ab74f  [503766, 503767]   87643.0
# 28561  fffdc2ac-bde4-4e4c-a5bd-0e6c6e49ad91          [430833]   64772.0
# 28562  ffff90c3-63c4-4dee-a21d-6b2b113f4f80          [509409]   86451.0
#
#        mtgo_foil_id  tcgplayer_id  cardmarket_id  \
# 0           15871.0        3094.0         3081.0
# 1           49284.0       69965.0       262945.0
# 2               NaN      196536.0       391692.0
# 3           22610.0       12835.0        12551.0
# 4           12638.0        6412.0        10604.0
# ...             ...           ...            ...
# 28558       64647.0      136683.0       298834.0
# 28559           NaN      276869.0       665173.0
# 28560           NaN      230214.0       530502.0
# 28561       64773.0      132234.0       298282.0
# 28562           NaN      233631.0       542666.0
#
#                                          name lang  ...  \
# 0                                  Static Orb   en  ...
# 1                         Sensory Deprivation   en  ...
# 2                              Road of Return   en  ...
# 3                                  Storm Crow   en  ...
# 4                              Walking Sponge   en  ...
# ...                                       ...  ...  ...
# 28558                        Without Weakness   en  ...
# 28559                 Firesong and Sunspeaker   en  ...
# 28560  Toralf, God of Fury // Toralf's Hammer   en  ...
# 28561                       Samut, the Tested   en  ...
# 28562                            Sinew Sliver   en  ...
#
#                                               card_faces frame_effects  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 28558                                                NaN           NaN
# 28559                                                NaN   [legendary]
# 28560  [{'object': 'card_face', 'name': 'Toralf, God ...   [legendary]
# 28561                                                NaN           NaN
# 28562                                                NaN           NaN
#
#       tcgplayer_etched_id promo_types  loyalty life_modifier hand_modifier  \
# 0                     NaN         NaN      NaN           NaN           NaN
# 1                     NaN         NaN      NaN           NaN           NaN
# 2                     NaN         NaN      NaN           NaN           NaN
# 3                     NaN         NaN      NaN           NaN           NaN
# 4                     NaN         NaN      NaN           NaN           NaN
# ...                   ...         ...      ...           ...           ...
# 28558                 NaN         NaN      NaN           NaN           NaN
# 28559                 NaN         NaN      NaN           NaN           NaN
# 28560                 NaN         NaN      NaN           NaN           NaN
# 28561                 NaN         NaN        4           NaN           NaN
# 28562                 NaN         NaN      NaN           NaN           NaN
#
#       attraction_lights  color_indicator content_warning
# 0                   NaN              NaN             NaN
# 1                   NaN              NaN             NaN
# 2                   NaN              NaN             NaN
# 3                   NaN              NaN             NaN
# 4                   NaN              NaN             NaN
# ...                 ...              ...             ...
# 28558               NaN              NaN             NaN
# 28559               NaN              NaN             NaN
# 28560               NaN              NaN             NaN
# 28561               NaN              NaN             NaN
# 28562               NaN              NaN             NaN
#
# [28563 rows x 79 columns]
